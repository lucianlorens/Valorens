# %%
import pandas as pd

# %%
df_raw = pd.read_csv('dre_sliced.csv', encoding='latin-1', sep=';')

# %%
df_raw.tail()
# Out:
#       Unnamed: 0    EMPRESA                                     CONTA  \
# 1399        1399  AMBEV S/A                               IR Diferido
# 1400        1400  AMBEV S/A  Participações/Contribuições Estatutárias
# 1401        1401  AMBEV S/A  Reversão dos Juros sobre Capital Próprio
# 1402        1402  AMBEV S/A     Part. de Acionistas Não Controladores
# 1403        1403  AMBEV S/A                 Lucro/Prejuízo do Período
#
#      TRIMESTRE  VALOR
# 1399   1T/2013    -70
# 1400   1T/2013      0
# 1401   1T/2013      0
# 1402   1T/2013      0
# 1403   1T/2013  9,768

# %%
df_raw.count()
# Out:
# Unnamed: 0    1404
# EMPRESA       1404
# CONTA         1404
# TRIMESTRE     1404
# VALOR         1269
# dtype: int64

# %%
df_raw.head()
# Out:
#    Unnamed: 0     EMPRESA                                     CONTA TRIMESTRE  \
# 0           0  ABC Brasil      Receitas da Intermediação Financeira   4T/2017
# 1           1  ABC Brasil      Despesas da Intermediação Financeira   4T/2017
# 2           2  ABC Brasil  Resultado Bruto Intermediação Financeira   4T/2017
# 3           3  ABC Brasil     Outras Despesas/Receitas Operacionais   4T/2017
# 4           4  ABC Brasil         Receitas de Prestação de Serviços   4T/2017
#
#       VALOR
# 0   814,726
# 1  -662,264
# 2   152,462
# 3   -28,155
# 4    83,697

# %%
df_detailed_values = df_raw.pivot_table( 'VALOR', ['EMPRESA', 'TRIMESTRE'], 'CONTA')
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-25-030c72d97f59> in <module>()
# ----> 1 df_detailed_values = df_raw.pivot_table( 'VALOR', ['EMPRESA', 'TRIMESTRE'], 'CONTA')
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#    5298                            aggfunc=aggfunc, fill_value=fill_value,
#    5299                            margins=margins, dropna=dropna,
# -> 5300                            margins_name=margins_name)
#    5301
#    5302     def stack(self, level=-1, dropna=True):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#      81
#      82     grouped = data.groupby(keys, observed=dropna)
# ...

# %%
df_pivoted = df_raw.pivot_table(index='Unnamed: 0', columns='CONTA', values=['VALOR'], aggfunc='first')

# %%
df_pivoted.head()
# Out:
#                                           VALOR                            \
# CONTA      Custo de Bens e/ou Serviços Vendidos Deduções da Receita Bruta
# Unnamed: 0
# 0                                           NaN                       NaN
# 1                                           NaN                       NaN
# 2                                           NaN                       NaN
# 3                                           NaN                       NaN
# 4                                           NaN                       NaN
#
#                                                               \
# CONTA      Despesas Despesas Com Vendas Despesas Financeiras
# Unnamed: 0
# 0               NaN                 NaN                  NaN
# 1               NaN                 NaN                  NaN
# 2               NaN                 NaN                  NaN
# 3               NaN                 NaN                  NaN
# ...

# %%
df_pivoted.to_csv('df_pivoted.csv', sep=';', encoding='latin-1')
