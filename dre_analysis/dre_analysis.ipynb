# %%
import pandas as pd

# %%
df_raw = pd.read_csv('DRE.csv', encoding='latin-1', sep=';')
df_raw.head()
# Out:
#       EMPRESA                                     CONTA TRIMESTRE     VALOR
# 0  ABC Brasil      Receitas da Intermediação Financeira   4T/2017   814,726
# 1  ABC Brasil      Despesas da Intermediação Financeira   4T/2017  -662,264
# 2  ABC Brasil  Resultado Bruto Intermediação Financeira   4T/2017   152,462
# 3  ABC Brasil     Outras Despesas/Receitas Operacionais   4T/2017   -28,155
# 4  ABC Brasil         Receitas de Prestação de Serviços   4T/2017    83,697

# %%
df_raw
# Out:
#             EMPRESA                                        CONTA TRIMESTRE  \
# 0        ABC Brasil         Receitas da Intermediação Financeira   4T/2017
# 1        ABC Brasil         Despesas da Intermediação Financeira   4T/2017
# 2        ABC Brasil     Resultado Bruto Intermediação Financeira   4T/2017
# 3        ABC Brasil        Outras Despesas/Receitas Operacionais   4T/2017
# 4        ABC Brasil            Receitas de Prestação de Serviços   4T/2017
# 5        ABC Brasil                          Despesas de Pessoal   4T/2017
# 6        ABC Brasil              Outras Despesas Administrativas   4T/2017
# 7        ABC Brasil                         Despesas Tributárias   4T/2017
# 8        ABC Brasil                 Outras Receitas Operacionais   4T/2017
# 9        ABC Brasil                 Outras Despesas Operacionais   4T/2017
# 10       ABC Brasil        Resultado da Equivalência Patrimonial   4T/2017
# ...

# %%
df_grouped = df_raw.groupby('EMPRESA')
df_grouped.head()
# Out:
#                EMPRESA                                     CONTA TRIMESTRE  \
# 0           ABC Brasil      Receitas da Intermediação Financeira   4T/2017
# 1           ABC Brasil      Despesas da Intermediação Financeira   4T/2017
# 2           ABC Brasil  Resultado Bruto Intermediação Financeira   4T/2017
# 3           ABC Brasil     Outras Despesas/Receitas Operacionais   4T/2017
# 4           ABC Brasil         Receitas de Prestação de Serviços   4T/2017
# 924          AMBEV S/A     Receita Bruta de Vendas e/ou Serviços   4T/2017
# 925          AMBEV S/A                 Deduções da Receita Bruta   4T/2017
# 926          AMBEV S/A   Receita Líquida de Vendas e/ou Serviços   4T/2017
# 927          AMBEV S/A      Custo de Bens e/ou Serviços Vendidos   4T/2017
# 928          AMBEV S/A                           Resultado Bruto   4T/2017
# 1404       VITALYZE.ME     Receita Bruta de Vendas e/ou Serviços   4T/2017
# ...
